# %%
import pandas as pd
import dask.dataframe as dd
import warnings 
warnings.filterwarnings("ignore")

# %%
path = r"C:\Users\jose.valclemir\Downloads\part-00009-852b438a-2b8f-4cdd-86c8-23f8e32abf0c-c000.csv"

# %%
dtype={'estabelecimento_municipio_codigo': 'object',
      'paciente_endereco_coIbgeMunicipio': 'object',
      'paciente_endereco_coPais': 'object',
      'vacina_grupoAtendimento_codigo': 'object',
      'paciente_endereco_coIbgeMunicipio': 'object',
      'paciente_idade': "object",
      'paciente_racaCor_codigo': "object"}

# %%
df = dd.read_csv(path, sep=";", dtype=dtype)

# %%
df = df[(df['paciente_enumSexoBiologico'] == "M") & (df['paciente_endereco_nmMunicipio'] == "FORTALEZA")]

# %%
df = df.compute()

# %%
df
# Out:
#                                      document_id  \
# 42     1b5d85cf-fbbb-4c60-8730-e155448c49fe-i0b0
# 216    7fa7196c-1eec-4465-9ee8-9b7ad1fbfa0a-i0b0
# 727    ca4c5d88-3c5d-4032-88a6-b1fc647fc45f-i0b0
# 1011   85e9c885-dfc2-48e9-a979-7a819362576b-i0b0
# 1944   b98f2d9c-cdf2-4aa6-ae45-aa6e636ed347-i0b0
# ...                                          ...
# 29461  a18ed02d-bcd0-403f-ad09-86e7a14b47f7-i0b0
# 29547  dbd15c73-08c9-4360-8db4-7e302b1cf42e-i0b0
# 29759  670dbc6d-c91e-418f-9a42-1ab117934035-i0b0
# 29820  93cde3a7-5866-4e70-a3a6-68307076c5be-i0b0
# 29855  a70c8b95-54df-4cd6-9b26-ef4d72137092-i0b0
#
#                                              paciente_id paciente_idade  \
# 42     4e29a813bbf7a8d4df0e9f4e53f1ebeeede6b16a2dcee3...             60
# 216    7c0807439c8cd0a6b4321cfa2396efbe3a7ece8c264e72...             14
# 727    a64e5ccbd25da20abae2a3c300938b06947adee932e65c...             12
# 1011   a825d017d0a95f23e3294caf1b77aea76d040fded5f86b...             16
# 1944   793e949fb33ca04cefece8baefe04688649e57574c2bef...              9
# ...                                                  ...            ...
# 29461  ce72f661ec061b91c72c07bbf6a3e04c2644f18d1dbec7...             40
# 29547  606960379b0a9552ffbe493fa6d6715067cea1444701cc...             11
# 29759  2b064404bf41debeb218d00bfc956038e28b494ca7a165...             11
# 29820  0c29a285449399c8b4adeac7a8a95ec738fc5f49d42a21...             83
# 29855  63363b0e4cdec6e83de8e51ba72821704f141ae2bb096f...             53
#
#       paciente_dataNascimento paciente_enumSexoBiologico  \
# 42                 1961-06-06                          M
# 216                2007-06-16                          M
# 727                2009-11-17                          M
# 1011               2005-08-31                          M
# 1944               2012-10-01                          M
# ...                       ...                        ...
# 29461              1981-08-24                          M
# 29547              2010-04-30                          M
# 29759              2011-01-11                          M
# 29820              1937-07-17                          M
# 29855              1968-01-21                          M
#
#       paciente_racaCor_codigo paciente_racaCor_valor  \
# 42                         03                  PARDA
# 216                        03                  PARDA
# 727                        99         SEM INFORMACAO
# 1011                       99         SEM INFORMACAO
# 1944                       03                  PARDA
# ...                       ...                    ...
# 29461                      04                AMARELA
# 29547                      03                  PARDA
# 29759                      03                  PARDA
# 29820                      03                  PARDA
# 29855                      03                  PARDA
#
#       paciente_endereco_coIbgeMunicipio paciente_endereco_coPais  \
# 42                               230440                       10
# 216                              230440                       10
# 727                              230440                       10
# 1011                             230440                       10
# 1944                             230440                       10
# ...                                 ...                      ...
# 29461                            230440                       10
# 29547                            230440                       10
# 29759                            230440                       10
# 29820                            230440                       10
# 29855                            230440                       10
#
#       paciente_endereco_nmMunicipio  ... vacina_categoria_codigo  \
# 42                        FORTALEZA  ...                     9.0
# 216                       FORTALEZA  ...                     9.0
# 727                       FORTALEZA  ...                     9.0
# 1011                      FORTALEZA  ...                     9.0
# 1944                      FORTALEZA  ...                     9.0
# ...                             ...  ...                     ...
# 29461                     FORTALEZA  ...                     9.0
# 29547                     FORTALEZA  ...                     9.0
# 29759                     FORTALEZA  ...                     NaN
# 29820                     FORTALEZA  ...                     2.0
# 29855                     FORTALEZA  ...                     9.0
#
#         vacina_categoria_nome vacina_lote  vacina_fabricante_nome  \
# 42     Trabalhadores de Saúde      FL1939                  PFIZER
# 216    Trabalhadores de Saúde      FH4750                  PFIZER
# 727    Trabalhadores de Saúde     32010BD                  PFIZER
# 1011   Trabalhadores de Saúde      FH4750                  PFIZER
# 1944   Trabalhadores de Saúde     210439A        SINOVAC/BUTANTAN
# ...                       ...         ...                     ...
# 29461  Trabalhadores de Saúde  217VCD234Z     ASTRAZENECA/FIOCRUZ
# 29547  Trabalhadores de Saúde      FP1176  Pendente Identificação
# 29759                     NaN      FN5988  Pendente Identificação
# 29820            Faixa Etária      210056        SINOVAC/BUTANTAN
# 29855  Trabalhadores de Saúde      FM3457                  PFIZER
#
#             vacina_fabricante_referencia vacina_dataAplicacao  \
# 42        PFIZER-BIONTECH/46070868000169           2022-02-03
# 216       PFIZER-BIONTECH/46070868000169           2021-11-06
# 727       PFIZER-BIONTECH/46070868000169           2021-11-29
# 1011      PFIZER-BIONTECH/46070868000169           2021-10-28
# 1944     SINOVAC-BUTANTAN/61189445000156           2022-02-12
# ...                                  ...                  ...
# 29461  OXFORD-ASTRAZENECA/33781055000135           2021-09-22
# 29547     PFIZER-BIONTECH/46070868000169           2022-01-18
# 29759        Organization/46070868000169           2022-02-25
# 29820        Organization/61189445000156           2021-03-20
# 29855     PFIZER-BIONTECH/46070868000169           2022-01-14
#
#       vacina_descricao_dose vacina_codigo  \
# 42                  Reforço            87
# 216                 2ª Dose            87
# 727                 1ª Dose            87
# 1011                2ª Dose            87
# 1944                1ª Dose            86
# ...                     ...           ...
# 29461               2ª Dose            85
# 29547               1ª Dose            99
# 29759               1ª Dose            99
# 29820               1ª Dose            86
# 29855               Reforço            87
#
#                                      vacina_nome         sistema_origem
# 42                   COVID-19 PFIZER - COMIRNATY  Fastmedic - FastSaude
# 216                  COVID-19 PFIZER - COMIRNATY  Fastmedic - FastSaude
# 727                  COVID-19 PFIZER - COMIRNATY  Fastmedic - FastSaude
# 1011                 COVID-19 PFIZER - COMIRNATY  Fastmedic - FastSaude
# 1944       COVID-19 SINOVAC/BUTANTAN - CORONAVAC  Fastmedic - FastSaude
# ...                                          ...                    ...
# 29461  COVID-19 ASTRAZENECA/FIOCRUZ - COVISHIELD  Fastmedic - FastSaude
# 29547     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY  Fastmedic - FastSaude
# 29759     COVID-19 PEDIÁTRICA - PFIZER COMIRNATY             IntegraSUS
# 29820      COVID-19 SINOVAC/BUTANTAN - CORONAVAC               Novo PNI
# 29855                COVID-19 PFIZER - COMIRNATY  Fastmedic - FastSaude
#
# [220941 rows x 32 columns]
