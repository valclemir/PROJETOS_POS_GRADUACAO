# %%
import pandas as pd 
import numpy as np 
import requests as res
from warnings import simplefilter
import seaborn as sns

simplefilter("ignore")

# %%
response = res.get("https://apisidra.ibge.gov.br/values/t/5457/n6/2300903,2306306,2306405,2310209,2310704,2312403,2312601,2313500,2313807,2302206,2303501,2302800,2303006,2304608,2310407,2301208,2301406,2302107,2302909,2305100,2306504,2309102,2309805,2310100,2311603,2306603,2300754,2310258,2313351,2313559,2313757,2303956,2310852,2300150,2301950,2309458/v/215,8331/p/last%201/c782/all").json()

# %%
columns = []
for i in pd.DataFrame(response).iloc[0]:
    columns.append(i)

# %%
df = pd.DataFrame(response).iloc[1:, :]

# %%
df.columns = columns

# %%
df.head()
# Out:
#   Nível Territorial (Código) Nível Territorial Unidade de Medida (Código)  \
# 1                          6         Município                         40
# 2                          6         Município                         40
# 3                          6         Município                         40
# 4                          6         Município                         40
# 5                          6         Município                         40
#
#   Unidade de Medida Valor Município (Código)      Município Variável (Código)  \
# 1         Mil Reais  6680            2300903  Apuiarés (CE)               215
# 2         Mil Reais     -            2300903  Apuiarés (CE)               215
# 3         Mil Reais     -            2300903  Apuiarés (CE)               215
# 4         Mil Reais     -            2300903  Apuiarés (CE)               215
# 5         Mil Reais   ...            2300903  Apuiarés (CE)               215
#
#             Variável Ano (Código)   Ano  \
# 1  Valor da produção         2020  2020
# 2  Valor da produção         2020  2020
# 3  Valor da produção         2020  2020
# 4  Valor da produção         2020  2020
# 5  Valor da produção         2020  2020
#
#   Produto das lavouras temporárias e permanentes (Código)  \
# 1                                                  0
# 2                                              40129
# 3                                              40092
# 4                                              45982
# 5                                              40329
#
#   Produto das lavouras temporárias e permanentes
# 1                                          Total
# 2                                        Abacate
# 3                                       Abacaxi*
# 4                                           Açaí
# 5                                  Alfafa fenada

# %%
df[df["Município"].str.contains("(CE)")].head()
# Out:
#   Nível Territorial (Código) Nível Territorial Unidade de Medida (Código)  \
# 1                          6         Município                         40
# 2                          6         Município                         40
# 3                          6         Município                         40
# 4                          6         Município                         40
# 5                          6         Município                         40
#
#   Unidade de Medida Valor Município (Código)      Município Variável (Código)  \
# 1         Mil Reais  6680            2300903  Apuiarés (CE)               215
# 2         Mil Reais     -            2300903  Apuiarés (CE)               215
# 3         Mil Reais     -            2300903  Apuiarés (CE)               215
# 4         Mil Reais     -            2300903  Apuiarés (CE)               215
# 5         Mil Reais   ...            2300903  Apuiarés (CE)               215
#
#             Variável Ano (Código)   Ano  \
# 1  Valor da produção         2020  2020
# 2  Valor da produção         2020  2020
# 3  Valor da produção         2020  2020
# 4  Valor da produção         2020  2020
# 5  Valor da produção         2020  2020
#
#   Produto das lavouras temporárias e permanentes (Código)  \
# 1                                                  0
# 2                                              40129
# 3                                              40092
# 4                                              45982
# 5                                              40329
#
#   Produto das lavouras temporárias e permanentes
# 1                                          Total
# 2                                        Abacate
# 3                                       Abacaxi*
# 4                                           Açaí
# 5                                  Alfafa fenada

# %%
df.columns
# Out:
# Index(['Nível Territorial (Código)', 'Nível Territorial',
#        'Unidade de Medida (Código)', 'Unidade de Medida', 'Valor',
#        'Município (Código)', 'Município', 'Variável (Código)', 'Variável',
#        'Ano (Código)', 'Ano',
#        'Produto das lavouras temporárias e permanentes (Código)',
#        'Produto das lavouras temporárias e permanentes'],
#       dtype='object')

# %%
df = df[df["Município"].str.contains("CE")]

# %%
df["Valor"] = df["Valor"].replace("-", 0).replace("...", 0).astype(float)

# %%
columns_select = ["Município", "Ano", "Valor", ]
columns_groupby = ["Município", "Ano",]

# %%
custo_total_por_municipio_e_ano = df[columns_select].groupby(columns_groupby).sum().reset_index().sort_values("Valor", ascending=False)

# %%
media = custo_total_por_municipio_e_ano["Valor"].mean()

# %%
desvio_padrao = custo_total_por_municipio_e_ano["Valor"].std()

# %%
custo_total_por_municipio_e_ano["Z-SCORE"] = (custo_total_por_municipio_e_ano["Valor"] - media) / desvio_padrao
custo_total_por_municipio_e_ano["% COEF_VAR"] = round((desvio_padrao / media) * 100, 2)
custo_total_por_municipio_e_ano["% DISTANCIA_DA_MEDIA "] = round((1 - (desvio_padrao / media)) * 100, 2)

# %%
custo_total_por_municipio_e_ano
# Out:
#                        Município   Ano     Valor   Z-SCORE  % COEF_VAR  \
# 16                Itapipoca (CE)  2020  162938.0  2.579692       74.82
# 7                  Beberibe (CE)  2020  159494.0  2.496913       74.82
# 24                Paraipaba (CE)  2020  125092.0  1.670043       74.82
# 32                   Trairi (CE)  2020  123468.0  1.631009       74.82
# 20                    Ocara (CE)  2020  121340.0  1.579862       74.82
# 11                 Cascavel (CE)  2020   93644.0  0.914174       74.82
# 1                  Amontada (CE)  2020   89108.0  0.805149       74.82
# 8                   Canindé (CE)  2020   89076.0  0.804380       74.82
# 4                   Aratuba (CE)  2020   74559.0  0.455456       74.82
# 28                 Redenção (CE)  2020   67624.0  0.288769       74.82
# 12               Chorozinho (CE)  2020   66426.0  0.259975       74.82
# 25                 Paramoti (CE)  2020   62670.0  0.169697       74.82
# 33                   Tururu (CE)  2020   60068.0  0.107157       74.82
# 5                  Barreira (CE)  2020   58078.0  0.059326       74.82
# 10                 Caridade (CE)  2020   54624.0 -0.023692       74.82
# 15                  Itapajé (CE)  2020   54410.0 -0.028836       74.82
# 3                 Aracoiaba (CE)  2020   52946.0 -0.064024       74.82
# 26               Pentecoste (CE)  2020   45416.0 -0.245011       74.82
# 9                Capistrano (CE)  2020   43826.0 -0.283228       74.82
# 6                  Baturité (CE)  2020   43046.0 -0.301976       74.82
# 35              Uruburetama (CE)  2020   42993.0 -0.303250       74.82
# 19                  Mulungu (CE)  2020   37097.0 -0.444963       74.82
# 17                 Itapiúna (CE)  2020   35956.0 -0.472388       74.82
# 23                 Paracuru (CE)  2020   29212.0 -0.634483       74.82
# 34                   Umirim (CE)  2020   28216.0 -0.658423       74.82
# 18                  Itatira (CE)  2020   27678.0 -0.671354       74.82
# 29  São Gonçalo do Amarante (CE)  2020   24054.0 -0.758458       74.82
# 2                  Apuiarés (CE)  2020   21812.0 -0.812346       74.82
# 22                 Palmácia (CE)  2020   20160.0 -0.852053       74.82
# 27              Pindoretama (CE)  2020   18714.0 -0.886808       74.82
# 21                   Pacoti (CE)  2020   17172.0 -0.923871       74.82
# 31                Tejuçuoca (CE)  2020   16578.0 -0.938148       74.82
# 30         São Luís do Curu (CE)  2020   11750.0 -1.054192       74.82
# 13          General Sampaio (CE)  2020    9322.0 -1.112550       74.82
# 0                   Acarape (CE)  2020    7028.0 -1.167687       74.82
# 14             Guaramiranga (CE)  2020    6355.0 -1.183863       74.82
#
#     % DISTANCIA_DA_MEDIA
# 16                  25.18
# 7                   25.18
# 24                  25.18
# 32                  25.18
# 20                  25.18
# 11                  25.18
# 1                   25.18
# 8                   25.18
# 4                   25.18
# 28                  25.18
# 12                  25.18
# 25                  25.18
# 33                  25.18
# 5                   25.18
# 10                  25.18
# 15                  25.18
# 3                   25.18
# 26                  25.18
# 9                   25.18
# 6                   25.18
# 35                  25.18
# 19                  25.18
# 17                  25.18
# 23                  25.18
# 34                  25.18
# 18                  25.18
# 29                  25.18
# 2                   25.18
# 22                  25.18
# 27                  25.18
# 21                  25.18
# 31                  25.18
# 30                  25.18
# 13                  25.18
# 0                   25.18
# 14                  25.18

# %%
columns_select = ["Município", "Ano", "Valor","Produto das lavouras temporárias e permanentes"]
columns_groupby = ["Município", "Ano", "Produto das lavouras temporárias e permanentes"]
custo_total_por_municipio_ano_e_produtos = df[columns_select].groupby(columns_groupby).sum().reset_index()

# %%
custo_total_por_municipio_ano_e_produtos.head()
# Out:
#       Município   Ano Produto das lavouras temporárias e permanentes  Valor
# 0  Acarape (CE)  2020                                        Abacate    0.0
# 1  Acarape (CE)  2020                                       Abacaxi*    0.0
# 2  Acarape (CE)  2020                                  Alfafa fenada    0.0
# 3  Acarape (CE)  2020                    Algodão arbóreo (em caroço)    0.0
# 4  Acarape (CE)  2020                   Algodão herbáceo (em caroço)    0.0

# %%
media = custo_total_por_municipio_ano_e_produtos["Valor"].mean()
desvio_padrao = custo_total_por_municipio_ano_e_produtos["Valor"].std()

# %%
custo_total_por_municipio_ano_e_produtos["Z-SCORE"] = (custo_total_por_municipio_ano_e_produtos["Valor"] - media) / desvio_padrao
custo_total_por_municipio_ano_e_produtos["% COEF_VAR"] = round( (desvio_padrao / media * 100) , 2)
custo_total_por_municipio_ano_e_produtos["% DISTANCIA_DA_MEDIA"] = round((1 - (desvio_padrao / media)) * 100, 2)

# %%
custo_total_por_municipio_ano_e_produtos
# Out:
#              Município   Ano Produto das lavouras temporárias e permanentes  \
# 0         Acarape (CE)  2020                                        Abacate
# 1         Acarape (CE)  2020                                       Abacaxi*
# 2         Acarape (CE)  2020                                  Alfafa fenada
# 3         Acarape (CE)  2020                    Algodão arbóreo (em caroço)
# 4         Acarape (CE)  2020                   Algodão herbáceo (em caroço)
# ...                ...   ...                                            ...
# 2587  Uruburetama (CE)  2020                                Trigo (em grão)
# 2588  Uruburetama (CE)  2020                            Triticale (em grão)
# 2589  Uruburetama (CE)  2020                            Tungue (fruto seco)
# 2590  Uruburetama (CE)  2020                               Urucum (semente)
# 2591  Uruburetama (CE)  2020                                            Uva
#
#       Valor   Z-SCORE  % COEF_VAR  % DISTANCIA_DA_MEDIA
# 0       0.0 -0.162674      614.73               -514.73
# 1       0.0 -0.162674      614.73               -514.73
# 2       0.0 -0.162674      614.73               -514.73
# 3       0.0 -0.162674      614.73               -514.73
# 4       0.0 -0.162674      614.73               -514.73
# ...     ...       ...         ...                   ...
# 2587    0.0 -0.162674      614.73               -514.73
# 2588    0.0 -0.162674      614.73               -514.73
# 2589    0.0 -0.162674      614.73               -514.73
# 2590    0.0 -0.162674      614.73               -514.73
# 2591    0.0 -0.162674      614.73               -514.73
#
# [2592 rows x 7 columns]

# %%
custo_total_por_municipio_ano_e_produtos[custo_total_por_municipio_ano_e_produtos["Valor"] != 0]
# Out:
#              Município   Ano Produto das lavouras temporárias e permanentes  \
# 7         Acarape (CE)  2020                               Arroz (em casca)
# 11        Acarape (CE)  2020                                 Banana (cacho)
# 24        Acarape (CE)  2020                               Castanha de caju
# 29        Acarape (CE)  2020                                  Coco-da-baía*
# 33        Acarape (CE)  2020                                 Fava (em grão)
# ...                ...   ...                                            ...
# 2566  Uruburetama (CE)  2020                                          Mamão
# 2567  Uruburetama (CE)  2020                                       Mandioca
# 2568  Uruburetama (CE)  2020                                          Manga
# 2574  Uruburetama (CE)  2020                                Milho (em grão)
# 2586  Uruburetama (CE)  2020                                          Total
#
#         Valor   Z-SCORE  % COEF_VAR  % DISTANCIA_DA_MEDIA
# 7        29.0 -0.156566      614.73               -514.73
# 11      119.0 -0.137610      614.73               -514.73
# 24      943.0  0.035941      614.73               -514.73
# 29       30.0 -0.156355      614.73               -514.73
# 33      245.0 -0.111072      614.73               -514.73
# ...       ...       ...         ...                   ...
# 2566    270.0 -0.105807      614.73               -514.73
# 2567    170.0 -0.126869      614.73               -514.73
# 2568    930.0  0.033203      614.73               -514.73
# 2574   1503.0  0.153888      614.73               -514.73
# 2586  21493.0  4.364185      614.73               -514.73
#
# [430 rows x 7 columns]

# %%
sns.distplot(custo_total_por_municipio_ano_e_produtos["Valor"]);

# %%
desvio_padrao / media
# Out:
# 6.14726331679275

# %%
desvio_padrao
# Out:
# 4747.883409356962

# %%
media
# Out:
# 772.3572530864197

# %%
from sklearn.datasets import make_blobs
from sklearn.metrics import accuracy_score
from tensorflow.keras.models import load_model
from tensorflow.keras.utils import to_categorical
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input
from tensorflow.keras.layers import Dense, Dropout
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import concatenate
import numpy as np

from numpy import argmax

def fit_model(trainX, trainy):
    # define model
    model = Sequential()
    #model.add(Dense(25, input_dim=10, activation='relu'))
    model.add(Dense(units=100, input_dim=10, activation='relu'))
    model.add(Dropout(0.2))
    # Hidden layer
    model.add(Dense(units=80, activation='relu'))
    model.add(Dropout(0.2))
    # Hidden layer
    model.add(Dense(units=10, activation='relu'))
    model.add(Dense(3, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    
    model.fit(trainX, trainy, epochs=10, verbose=0)
    return model
 
# load models from file
def load_all_models(n_models):
	all_models = list()
	for i in range(n_models):
		# define filename for this ensemble
		filename = 'models/model_' + str(i + 1) + '.h5'
		# load model from file
		model = load_model(filename)
		# add to list of members
		all_models.append(model)
		print('>loaded %s' % filename)
	return all_models
 
# define stacked model from multiple member input models
def define_stacked_model(members):
	# update all layers in all models to not be trainable
	for i in range(len(members)):
		model = members[i]
		for layer in model.layers:
			# make not trainable
			layer.trainable = False
			# rename to avoid 'unique layer name' issue
			layer._name = 'sub-modelo' + str(i+1) + '_' + layer.name
	# define multi-headed input
	ensemble_visible = [model.input for model in members];print(ensemble_visible)
	# concatenate merge output from each model
	ensemble_outputs = [model.output for model in members];print(ensemble_outputs)
	merge = concatenate(ensemble_outputs) ;print("MERGEEE", merge)
	hidden = Dense(50, activation='relu')(merge) ;print("hidden", hidden)
	output = Dense(3, activation='softmax')(merge) ;print("output", output)
	model = Model(inputs=ensemble_visible, outputs=output)
	# plot graph of ensemble
	plot_model(model, show_shapes=True, to_file='model_graph.png', show_layer_names=True)
	# compile
	model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
	return model
 
# fit a stacked model
def fit_stacked_model(model, inputX, inputy):
    print("Aqui", len(model.input))
	# prepare input data
    x_ =[]
    for  _ in range(len(model.input)):
        x_.append(inputX)
        
            
    X = [inputX for _ in range(len(model.input))]
	# encode output data
    inputy_enc = to_categorical(inputy)
    print(inputX.shape, len(x_), inputy_enc.shape, len(X), X[0].shape)
	# fit model
    model.fit(X, inputy_enc, epochs=100, verbose=1)
 # make a prediction with a stacked model
def predict_stacked_model(model, inputX):
	# prepare input data
	X = [inputX for _ in range(len(model.input))]
	# make prediction
	return model.predict(X, verbose=0)
 
# generate 2d classification dataset
X, y = make_blobs(n_samples=1000, centers=3, n_features=10, cluster_std=2, random_state=2)
# split into train and test
n_train = 100
trainX, testX = X[:n_train, :], X[n_train:, :]
trainy, testy = y[:n_train], y[n_train:]
print(trainX.shape, testX.shape)

n_members = 5
for i in range(n_members):
    # fit model
    model = fit_model(trainX, to_categorical(trainy, 3))
    # save model
    filename = 'models/model_' + str(i + 1) + '.h5'
    model.save(filename)
    print('>Saved %s' % filename)

# load all models
n_members = 5
members = load_all_models(n_members)
print('Loaded %d models' % len(members))
# define ensemble model
stacked_model = define_stacked_model(members)
print(testX.shape)
# fit stacked model on test dataset
fit_stacked_model(stacked_model, testX, testy)
# make predictions and evaluate
yhat = predict_stacked_model(stacked_model, testX)
yhat = argmax(yhat, axis=1)
acc = accuracy_score(testy, yhat)
print('Stacked Test Accuracy: %.3f' % acc)
# Out:
# (100, 10) (900, 10)

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.utils import plot_model
model = Sequential()
model.add(Dense(200, input_dim=25, activation='relu'))
model.add(Dense(3, activation='softmax'))
plot_model(model, to_file='model_plot_2.png', show_shapes=True, show_layer_names=True)

# %%
np.zeros(900 * 5).shape
# Out:
# (4500,)
